# %%
array = ["水","金","地","火","木","土","天","海","冥"]

#Forで表示
for array in array:
    print(array)

#Whileで表示
array2 = ["水","金","地","火","木","土","天","海","冥"]
i = 0 #何回目か
count = 0 #出力した回数

while count < 9:
  print(array2[i])
  i = i + 1
  count = count + 1
# Out:
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥
