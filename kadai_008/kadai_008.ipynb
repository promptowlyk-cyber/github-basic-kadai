# %%
import random
var = random.randint(1,100)
var > 0
print(var)

if var % 3 == 0 and var % 5 == 0:
  print("FizzBizz")
elif var % 3 == 0:
  print("Fizz")
elif var % 5 == 0:
  print("Bizz")
else :
  print(var)
# Out:
# 14
